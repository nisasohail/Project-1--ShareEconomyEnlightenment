# %%
#import the modules
import requests
import json

# %%
# Define a business ID
api_key='0rp6giKNdWp5zRL-cirM6maWp6SmOQLcIMFQY9YhMayUnrWm1CDACWbeNKI40bBZx2Any2_XAod2bduomwk5O77E6DPaVWrYBaWXYSKv6In9gHo3nfxMRLxV7jQqXXYx'
headers = {'Authorization': 'Bearer %s' % api_key}
api_key
# Out:
# '0rp6giKNdWp5zRL-cirM6maWp6SmOQLcIMFQY9YhMayUnrWm1CDACWbeNKI40bBZx2Any2_XAod2bduomwk5O77E6DPaVWrYBaWXYSKv6In9gHo3nfxMRLxV7jQqXXYx'

# %%
url='https://api.yelp.com/v3/businesses/search'
 
# In the dictionary, term can take values like food, cafes or businesses like McDonalds
params = {'term':'restaurant','location':'Texas'}

# %%
# Making a get request to the API
req=requests.get(url, params=params, headers=headers)
 
# proceed only if the status code is 200
print('The status code is {}'.format(req.status_code))
# Out:
# The status code is 200

# %%
# printing the text from the response 
json.loads(req.text)
# Out:
# {'businesses': [{'id': '237MSviehmCzD_wwKg4-zA',
#    'alias': 'bosscat-kitchen-and-libations-houston',
#    'name': 'Bosscat Kitchen & Libations',
#    'image_url': 'https://s3-media4.fl.yelpcdn.com/bphoto/AWDjoTwd0tpzg4HVDapqOg/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/bosscat-kitchen-and-libations-houston?adjust_creative=5U2yPz8oslPrIH9xoz3zhg&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=5U2yPz8oslPrIH9xoz3zhg',
#    'review_count': 1389,
#    'categories': [{'alias': 'newamerican', 'title': 'American (New)'},
#     {'alias': 'whiskeybars', 'title': 'Whiskey Bars'},
#     {'alias': 'breakfast_brunch', 'title': 'Breakfast & Brunch'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 29.7418, 'longitude': -95.450518},
#    'transactions': ['restaurant_reservation', 'pickup', 'delivery'],
#    'price': '$$',
#    'location': {'address1': '4310 Westheimer Rd',
#     'address2': 'Ste 150',
#     'address3': None,
#     'city': 'Houston',
#     'zip_code': '77027',
#     'country': 'US',
#     'state': 'TX',
#     'display_address': ['4310 Westheimer Rd', 'Ste 150', 'Houston, TX 77027']},
#    'phone': '+12815011187',
#    'display_phone': '(281) 501-1187',
#    'distance': 9068.955786437946},
#   {'id': 'Uxr2owVxThOp_lsSOqxbPw',
#    'alias': 'ritual-houston',
#    'name': 'Ritual',
#    'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/gQ7KvbIXSkaYbUJ9_oHxhw/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/ritual-houston?adjust_creative=5U2yPz8oslPrIH9xoz3zhg&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=5U2yPz8oslPrIH9xoz3zhg',
#    'review_count': 1265,
#    'categories': [{'alias': 'southern', 'title': 'Southern'},
#     {'alias': 'newamerican', 'title': 'American (New)'},
#     {'alias': 'steak', 'title': 'Steakhouses'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 29.78193, 'longitude': -95.38735},
#    'transactions': [],
#    'price': '$$',
#    'location': {'address1': '602 Studewood St',
#     'address2': None,
#     'address3': '',
#     'city': 'Houston',
#     'zip_code': '77007',
#     'country': 'US',
#     'state': 'TX',
#     'display_address': ['602 Studewood St', 'Houston, TX 77007']},
#    'phone': '+18322035180',
#    'display_phone': '(832) 203-5180',
#    'distance': 3380.456520282344},
#   {'id': 'RoU8KznQMrRFcIjYVtdZMw',
#    'alias': 'the-pit-room-houston',
#    'name': 'The Pit Room',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/kOrAG30CDxnW9FHW7nEL-Q/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/the-pit-room-houston?adjust_creative=5U2yPz8oslPrIH9xoz3zhg&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=5U2yPz8oslPrIH9xoz3zhg',
#    'review_count': 1471,
#    'categories': [{'alias': 'bbq', 'title': 'Barbeque'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 29.7342352703345,
#     'longitude': -95.3939679771603},
#    'transactions': [],
#    'price': '$$',
#    'location': {'address1': '1201 Richmond Ave',
#     'address2': '',
#     'address3': '',
#     'city': 'Houston',
#     'zip_code': '77006',
#     'country': 'US',
#     'state': 'TX',
#     'display_address': ['1201 Richmond Ave', 'Houston, TX 77006']},
#    'phone': '+12818881929',
#    'display_phone': '(281) 888-1929',
#    'distance': 4585.949510953171},
#   {'id': 'BKu4VGO2bW3nw8kc_ryumw',
#    'alias': 'bck-houston-4',
#    'name': 'BCK',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/6JlMlsDIcB53G02rvS05gw/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/bck-houston-4?adjust_creative=5U2yPz8oslPrIH9xoz3zhg&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=5U2yPz8oslPrIH9xoz3zhg',
#    'review_count': 640,
#    'categories': [{'alias': 'newamerican', 'title': 'American (New)'},
#     {'alias': 'cocktailbars', 'title': 'Cocktail Bars'},
#     {'alias': 'breakfast_brunch', 'title': 'Breakfast & Brunch'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 29.7887995448524,
#     'longitude': -95.388083953373},
#    'transactions': ['restaurant_reservation', 'pickup', 'delivery'],
#    'price': '$$',
#    'location': {'address1': '933 Studewood St',
#     'address2': '',
#     'address3': None,
#     'city': 'Houston',
#     'zip_code': '77008',
#     'country': 'US',
#     'state': 'TX',
#     'display_address': ['933 Studewood St', 'Houston, TX 77008']},
#    'phone': '+18328317155',
#    'display_phone': '(832) 831-7155',
#    'distance': 3947.653192634301},
#   {'id': 'Ga839ZKqLbJsHXcZhcM1eQ',
#    'alias': 'la-lucha-houston-4',
#    'name': 'La Lucha',
#    'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/7-mZ-C_HtC0exNUcyiZL8A/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/la-lucha-houston-4?adjust_creative=5U2yPz8oslPrIH9xoz3zhg&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=5U2yPz8oslPrIH9xoz3zhg',
#    'review_count': 184,
#    'categories': [{'alias': 'seafood', 'title': 'Seafood'},
#     {'alias': 'tradamerican', 'title': 'American (Traditional)'},
#     {'alias': 'bars', 'title': 'Bars'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 29.80193, 'longitude': -95.41033},
#    'transactions': [],
#    'price': '$$',
#    'location': {'address1': '1801 N Shepherd Dr',
#     'address2': None,
#     'address3': '',
#     'city': 'Houston',
#     'zip_code': '77008',
#     'country': 'US',
#     'state': 'TX',
#     'display_address': ['1801 N Shepherd Dr', 'Houston, TX 77008']},
#    'phone': '+17139554765',
#    'display_phone': '(713) 955-4765',
#    'distance': 6559.321827099166},
#   {'id': 'NNMvUp-r7sQt7Q2l-kO9wA',
#    'alias': 'the-breakfast-klub-houston-2',
#    'name': 'The Breakfast Klub',
#    'image_url': 'https://s3-media4.fl.yelpcdn.com/bphoto/VNNIyiBmg-jLAfkNUsby3Q/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/the-breakfast-klub-houston-2?adjust_creative=5U2yPz8oslPrIH9xoz3zhg&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=5U2yPz8oslPrIH9xoz3zhg',
#    'review_count': 4039,
#    'categories': [{'alias': 'breakfast_brunch', 'title': 'Breakfast & Brunch'},
#     {'alias': 'southern', 'title': 'Southern'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 29.73843, 'longitude': -95.38048},
#    'transactions': [],
#    'price': '$$',
#    'location': {'address1': '3711 Travis St',
#     'address2': '',
#     'address3': '',
#     'city': 'Houston',
#     'zip_code': '77002',
#     'country': 'US',
#     'state': 'TX',
#     'display_address': ['3711 Travis St', 'Houston, TX 77002']},
#    'phone': '+17135288561',
#    'display_phone': '(713) 528-8561',
#    'distance': 3370.053898864104},
#   {'id': 'kGbr_y_XxapZPnycxCV4Pg',
#    'alias': 'ambrosia-houston',
#    'name': 'Ambrosia',
#    'image_url': 'https://s3-media4.fl.yelpcdn.com/bphoto/5rYmD56X6bU0FEUs7tYynw/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/ambrosia-houston?adjust_creative=5U2yPz8oslPrIH9xoz3zhg&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=5U2yPz8oslPrIH9xoz3zhg',
#    'review_count': 838,
#    'categories': [{'alias': 'tapasmallplates', 'title': 'Tapas/Small Plates'},
#     {'alias': 'asianfusion', 'title': 'Asian Fusion'},
#     {'alias': 'wine_bars', 'title': 'Wine Bars'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 29.731809, 'longitude': -95.409689},
#    'transactions': ['restaurant_reservation'],
#    'price': '$$',
#    'location': {'address1': '2003 Lexington St',
#     'address2': '',
#     'address3': '',
#     'city': 'Houston',
#     'zip_code': '77098',
#     'country': 'US',
#     'state': 'TX',
#     'display_address': ['2003 Lexington St', 'Houston, TX 77098']},
#    'phone': '+18326494636',
#    'display_phone': '(832) 649-4636',
#    'distance': 5924.727148522327},
#   {'id': 'suffPaUlK64hJFkhO0Nn_Q',
#    'alias': 'the-rustic-houston-2',
#    'name': 'The Rustic',
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/vO4b-nDIagt_7S9g1wiQJQ/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/the-rustic-houston-2?adjust_creative=5U2yPz8oslPrIH9xoz3zhg&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=5U2yPz8oslPrIH9xoz3zhg',
#    'review_count': 359,
#    'categories': [{'alias': 'bars', 'title': 'Bars'},
#     {'alias': 'musicvenues', 'title': 'Music Venues'},
#     {'alias': 'tradamerican', 'title': 'American (Traditional)'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 29.7502708, 'longitude': -95.3595825},
#    'transactions': [],
#    'price': '$$',
#    'location': {'address1': '1836 Polk St',
#     'address2': '',
#     'address3': None,
#     'city': 'Houston',
#     'zip_code': '77003',
#     'country': 'US',
#     'state': 'TX',
#     'display_address': ['1836 Polk St', 'Houston, TX 77003']},
#    'phone': '+18323217799',
#    'display_phone': '(832) 321-7799',
#    'distance': 1456.1669431714247},
#   {'id': 'I1VlZBW80UL3E3NvahlqXg',
#    'alias': 'oporto-fooding-house-and-wine-houston',
#    'name': 'Oporto Fooding House & Wine',
#    'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/FlZnL3OYdlSN3yhhjBnLnw/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/oporto-fooding-house-and-wine-houston?adjust_creative=5U2yPz8oslPrIH9xoz3zhg&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=5U2yPz8oslPrIH9xoz3zhg',
#    'review_count': 869,
#    'categories': [{'alias': 'tapasmallplates', 'title': 'Tapas/Small Plates'},
#     {'alias': 'portuguese', 'title': 'Portuguese'},
#     {'alias': 'wine_bars', 'title': 'Wine Bars'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 29.7531384239378,
#     'longitude': -95.3802139853275},
#    'transactions': ['restaurant_reservation', 'pickup', 'delivery'],
#    'price': '$$',
#    'location': {'address1': '125 W Gray Ave',
#     'address2': 'Ste 500',
#     'address3': '',
#     'city': 'Houston',
#     'zip_code': '77019',
#     'country': 'US',
#     'state': 'TX',
#     'display_address': ['125 W Gray Ave', 'Ste 500', 'Houston, TX 77019']},
#    'phone': '+17135280115',
#    'display_phone': '(713) 528-0115',
#    'distance': 2243.4905689654634},
#   {'id': 'wnjQug5gfet04EZgpq19Rw',
#    'alias': 'the-french-fry-house-houston',
#    'name': 'The French Fry House',
#    'image_url': 'https://s3-media4.fl.yelpcdn.com/bphoto/0_qk61m6Oq9-0jEd5iOtFA/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/the-french-fry-house-houston?adjust_creative=5U2yPz8oslPrIH9xoz3zhg&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=5U2yPz8oslPrIH9xoz3zhg',
#    'review_count': 149,
#    'categories': [{'alias': 'tradamerican', 'title': 'American (Traditional)'},
#     {'alias': 'comfortfood', 'title': 'Comfort Food'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 29.7304474769317,
#     'longitude': -95.3601673990488},
#    'transactions': [],
#    'price': '$',
#    'location': {'address1': '3221 Ennis St',
#     'address2': '',
#     'address3': None,
#     'city': 'Houston',
#     'zip_code': '77004',
#     'country': 'US',
#     'state': 'TX',
#     'display_address': ['3221 Ennis St', 'Houston, TX 77004']},
#    'phone': '+17134975860',
#    'display_phone': '(713) 497-5860',
#    'distance': 3622.5845328817877},
#   {'id': 'mnRw8w8Fp7-b13Dmmpm70w',
#    'alias': 'graces-houston-3',
#    'name': "Grace's",
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/NjyF4IJWrgJSM6gsICnljA/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/graces-houston-3?adjust_creative=5U2yPz8oslPrIH9xoz3zhg&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=5U2yPz8oslPrIH9xoz3zhg',
#    'review_count': 748,
#    'categories': [{'alias': 'tradamerican', 'title': 'American (Traditional)'},
#     {'alias': 'breakfast_brunch', 'title': 'Breakfast & Brunch'},
#     {'alias': 'comfortfood', 'title': 'Comfort Food'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 29.737020211778,
#     'longitude': -95.4185060876135},
#    'transactions': [],
#    'price': '$$',
#    'location': {'address1': '3111 Kirby Dr',
#     'address2': '',
#     'address3': '',
#     'city': 'Houston',
#     'zip_code': '77098',
#     'country': 'US',
#     'state': 'TX',
#     'display_address': ['3111 Kirby Dr', 'Houston, TX 77098']},
#    'phone': '+17137286410',
#    'display_phone': '(713) 728-6410',
#    'distance': 6349.205254840426},
#   {'id': 'VQZF4hu7faCkUaJ9RDRpeQ',
#    'alias': 'local-foods-houston',
#    'name': 'Local Foods',
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/bKgWmpZo3lOkInGE3KyN4A/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/local-foods-houston?adjust_creative=5U2yPz8oslPrIH9xoz3zhg&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=5U2yPz8oslPrIH9xoz3zhg',
#    'review_count': 1477,
#    'categories': [{'alias': 'sandwiches', 'title': 'Sandwiches'},
#     {'alias': 'delis', 'title': 'Delis'},
#     {'alias': 'salad', 'title': 'Salad'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 29.7195096809181,
#     'longitude': -95.4164240674591},
#    'transactions': [],
#    'price': '$$',
#    'location': {'address1': '2424 Dunstan Rd',
#     'address2': '',
#     'address3': '',
#     'city': 'Houston',
#     'zip_code': '77005',
#     'country': 'US',
#     'state': 'TX',
#     'display_address': ['2424 Dunstan Rd', 'Houston, TX 77005']},
#    'phone': '+17135217800',
#    'display_phone': '(713) 521-7800',
#    'distance': 7289.546669017386},
#   {'id': 'pr9Hcn5fjpxWLZzIbNb8Cw',
#    'alias': 'lucilles-houston',
#    'name': "Lucille's",
#    'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/b5_u1ZGqXApZaLeYkof1GQ/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/lucilles-houston?adjust_creative=5U2yPz8oslPrIH9xoz3zhg&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=5U2yPz8oslPrIH9xoz3zhg',
#    'review_count': 756,
#    'categories': [{'alias': 'newamerican', 'title': 'American (New)'},
#     {'alias': 'southern', 'title': 'Southern'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 29.72388, 'longitude': -95.38515},
#    'transactions': ['delivery'],
#    'price': '$$',
#    'location': {'address1': '5512 La Branch St',
#     'address2': '',
#     'address3': '',
#     'city': 'Houston',
#     'zip_code': '77004',
#     'country': 'US',
#     'state': 'TX',
#     'display_address': ['5512 La Branch St', 'Houston, TX 77004']},
#    'phone': '+17135682505',
#    'display_phone': '(713) 568-2505',
#    'distance': 4990.8836261528295},
#   {'id': 'I5XqZRCCCbNjW66I88SIzA',
#    'alias': 'kulture-houston',
#    'name': 'Kulture',
#    'image_url': 'https://s3-media4.fl.yelpcdn.com/bphoto/vLjfIGpP-q8mZ1eGYv9a2Q/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/kulture-houston?adjust_creative=5U2yPz8oslPrIH9xoz3zhg&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=5U2yPz8oslPrIH9xoz3zhg',
#    'review_count': 255,
#    'categories': [{'alias': 'southern', 'title': 'Southern'},
#     {'alias': 'soulfood', 'title': 'Soul Food'},
#     {'alias': 'newamerican', 'title': 'American (New)'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 29.7545999989511,
#     'longitude': -95.3567959944427},
#    'transactions': [],
#    'price': '$$',
#    'location': {'address1': '701 Avenida De Las Americas',
#     'address2': 'Ste A',
#     'address3': None,
#     'city': 'Houston',
#     'zip_code': '77010',
#     'country': 'US',
#     'state': 'TX',
#     'display_address': ['701 Avenida De Las Americas',
#      'Ste A',
#      'Houston, TX 77010']},
#    'phone': '+17133579697',
#    'display_phone': '(713) 357-9697',
#    'distance': 985.2638705695078},
#   {'id': 'MtrXTHsxOCw0iCtOlPhrGQ',
#    'alias': 'jinya-ramen-bar-houston-3',
#    'name': 'JINYA Ramen Bar',
#    'image_url': 'https://s3-media4.fl.yelpcdn.com/bphoto/uWVAzPgj7fCYiikz_oht6g/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/jinya-ramen-bar-houston-3?adjust_creative=5U2yPz8oslPrIH9xoz3zhg&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=5U2yPz8oslPrIH9xoz3zhg',
#    'review_count': 2713,
#    'categories': [{'alias': 'ramen', 'title': 'Ramen'},
#     {'alias': 'cocktailbars', 'title': 'Cocktail Bars'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 29.742755, 'longitude': -95.379845},
#    'transactions': [],
#    'price': '$$',
#    'location': {'address1': '3201 Louisiana St',
#     'address2': 'Ste 105',
#     'address3': '',
#     'city': 'Houston',
#     'zip_code': '77006',
#     'country': 'US',
#     'state': 'TX',
#     'display_address': ['3201 Louisiana St', 'Ste 105', 'Houston, TX 77006']},
#    'phone': '+18329258596',
#    'display_phone': '(832) 925-8596',
#    'distance': 2960.974340807312},
#   {'id': 'lvPKIOptlfBKyg7f1vWd7w',
#    'alias': 'squable-houston',
#    'name': 'Squable',
#    'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/4GAPKQD0cB3Azp2oqvu8Gw/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/squable-houston?adjust_creative=5U2yPz8oslPrIH9xoz3zhg&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=5U2yPz8oslPrIH9xoz3zhg',
#    'review_count': 53,
#    'categories': [{'alias': 'modern_european', 'title': 'Modern European'},
#     {'alias': 'newamerican', 'title': 'American (New)'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 29.802594, 'longitude': -95.409436},
#    'transactions': [],
#    'location': {'address1': '632 W 19th St',
#     'address2': '',
#     'address3': None,
#     'city': 'Houston',
#     'zip_code': '77008',
#     'country': 'US',
#     'state': 'TX',
#     'display_address': ['632 W 19th St', 'Houston, TX 77008']},
#    'phone': '+18328347362',
#    'display_phone': '(832) 834-7362',
#    'distance': 6493.2066323508625},
#   {'id': 'TqbzDpUI9_SREzH_AfejlQ',
#    'alias': 'nancys-hustle-houston',
#    'name': "Nancy's Hustle",
#    'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/-9mSoQb-mu6LdHcOlgpOCA/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/nancys-hustle-houston?adjust_creative=5U2yPz8oslPrIH9xoz3zhg&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=5U2yPz8oslPrIH9xoz3zhg',
#    'review_count': 433,
#    'categories': [{'alias': 'newamerican', 'title': 'American (New)'},
#     {'alias': 'tapasmallplates', 'title': 'Tapas/Small Plates'},
#     {'alias': 'modern_european', 'title': 'Modern European'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 29.74551, 'longitude': -95.3520999},
#    'transactions': [],
#    'price': '$$',
#    'location': {'address1': '2704 Polk St',
#     'address2': '',
#     'address3': None,
#     'city': 'Houston',
#     'zip_code': '77003',
#     'country': 'US',
#     'state': 'TX',
#     'display_address': ['2704 Polk St', 'Houston, TX 77003']},
#    'phone': '+13465717931',
#    'display_phone': '(346) 571-7931',
#    'distance': 2084.3585415736316},
#   {'id': 'uz2OUI0fIJBRrFnfLUPWuQ',
#    'alias': 'yoyos-hot-dog-houston-14',
#    'name': "Yoyo's Hot Dog",
#    'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/TfX64197gXczdC48ccTj0A/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/yoyos-hot-dog-houston-14?adjust_creative=5U2yPz8oslPrIH9xoz3zhg&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=5U2yPz8oslPrIH9xoz3zhg',
#    'review_count': 712,
#    'categories': [{'alias': 'hotdog', 'title': 'Hot Dogs'},
#     {'alias': 'foodstands', 'title': 'Food Stands'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 29.7162012025613,
#     'longitude': -95.4146640004135},
#    'transactions': [],
#    'price': '$',
#    'location': {'address1': '5555 Morningside Dr',
#     'address2': None,
#     'address3': '',
#     'city': 'Houston',
#     'zip_code': '77005',
#     'country': 'US',
#     'state': 'TX',
#     'display_address': ['5555 Morningside Dr', 'Houston, TX 77005']},
#    'phone': '+17138396207',
#    'display_phone': '(713) 839-6207',
#    'distance': 7416.868117761163},
#   {'id': 'vck7wPLGT79YRiFbLJyRnQ',
#    'alias': 'cielito-cafe-houston-2',
#    'name': 'Cielito Cafe',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/b8xtw-_00Rr6PGW0yuRmUg/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/cielito-cafe-houston-2?adjust_creative=5U2yPz8oslPrIH9xoz3zhg&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=5U2yPz8oslPrIH9xoz3zhg',
#    'review_count': 110,
#    'categories': [{'alias': 'breakfast_brunch', 'title': 'Breakfast & Brunch'},
#     {'alias': 'mexican', 'title': 'Mexican'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 29.748475, 'longitude': -95.401941},
#    'transactions': [],
#    'location': {'address1': '1915 Dunlavy St',
#     'address2': '',
#     'address3': None,
#     'city': 'Houston',
#     'zip_code': '77006',
#     'country': 'US',
#     'state': 'TX',
#     'display_address': ['1915 Dunlavy St', 'Houston, TX 77006']},
#    'phone': '+18324095253',
#    'display_phone': '(832) 409-5253',
#    'distance': 4364.080564832941},
#   {'id': 'Y_alysR9cw4RZsOip0cQbw',
#    'alias': 'mico-s-hot-chicken-houston',
#    'name': 'Mico’s Hot Chicken',
#    'image_url': 'https://s3-media4.fl.yelpcdn.com/bphoto/rXh34sHTOin4slQ6Poo72Q/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/mico-s-hot-chicken-houston?adjust_creative=5U2yPz8oslPrIH9xoz3zhg&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=5U2yPz8oslPrIH9xoz3zhg',
#    'review_count': 40,
#    'categories': [{'alias': 'chickenshop', 'title': 'Chicken Shop'},
#     {'alias': 'southern', 'title': 'Southern'},
#     {'alias': 'foodtrucks', 'title': 'Food Trucks'}],
#    'rating': 5.0,
#    'coordinates': {'latitude': 29.7364923677041, 'longitude': -95.476171},
#    'transactions': [],
#    'location': {'address1': '2829 Chimney Rock Rd',
#     'address2': '',
#     'address3': None,
#     'city': 'Houston',
#     'zip_code': '77056',
#     'country': 'US',
#     'state': 'TX',
#     'display_address': ['2829 Chimney Rock Rd', 'Houston, TX 77056']},
#    'phone': '+13463035560',
#    'display_phone': '(346) 303-5560',
#    'distance': 11600.884819707555}],
#  'total': 2700,
#  'region': {'center': {'longitude': -95.35995483398438,
#    'latitude': 29.763025675716687}}}
